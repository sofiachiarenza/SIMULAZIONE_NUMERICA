# %% [markdown]
# # <span style="color:Purple"> Numerical Simulation Laboratory : Exercise 1 </span>

# %% [markdown]
# ## IMPORTANT: Guidelines for a proper conduct of the exercises
# 1. you should create code that is correct, simple, well organized, indented, commented, which uses self-explanatory names for variables and that is numerically efficient.
# 2. I expect a responsible interaction during the exercises: the questions should be more related to the conduction of the exercises and to the meaning of the results obtained than to the computational problems. Bugs are usual in coding; for this reason, sooner or later, one should learn to deal with them by oneself ... if you'll be able to, it will be your main achievement in this Laboratory!

# %% [markdown]
# ### Exercise 01.1
# - Test the Pseudo-Random Number generator downloaded from the NSL Ariel web site by estimating:

# %% [markdown]
# 1. $\langle r \rangle = \int_0^1 r dr = 1/2$. <font color="red">Make a picture of the estimation of $\langle r \rangle$ and its uncertainty (which corresponds to Standard Deviation of the mean for the estimation of $\langle r \rangle$) with a large number of *throws* $M$ (e.g. $M\ge 10^4$) as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties).

# %% [markdown]
# 2. $\sigma^2 = \int_0^1 (r-1/2)^2 dr = 1/12$. <font color="red">Make a picture of the estimation of $\sigma^2$ and its uncertainty (which corresponds to Standard Deviation of the mean for the estimation of $\langle (r-1/2)^2 \rangle$) with a large number of *throws* $M$ (e.g. $M\ge 10^4$) as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties).

# %% [markdown]
# The hypothesis is that the numbers $r$ are drawn from a uniform distribution. In Statistics we cannot prove that some random events are drawn from a particular distribution (Note, in fact, that such hypothesis is false: pseudo-random numbers are drawn from a deterministic algorithm!); we can try to estimate the probability that $r$ **are not** drawn from a uniform distribution. If this probability is low, we can safely reject this last hypothesis.
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
# Pearson's cumulative test statistic $\chi^2$ is a measure of the error between observations, $O_i$, and expected values, $E_i$:
# $$\chi^2 = \sum_{i} \frac{\left( O_i - E_i \right)^2}{E_i}$$
# The numerator is a squared distance between observations, $O_i$, and expected values, $E_i$, and thus should be compared (at the denominator) with the expected squared fluctuations (variance) of the relative distribution. Why variance = $E_i$?
# The probability of getting exactly $k$ (independent) successes, each one with probability $p$, in $n$ trials is given by the Binomial distribution (see <a href="https://en.wikipedia.org/wiki/Binomial_distribution">this Wikipedia link</a>):
# $$Pr(X=k) = {{n}\choose{k}} p^k (1-p)^{n-k} = \frac{n!}{k! (n-k)!} p^k (1-p)^{n-k}$$
# The average of the Binomial distribution is $\langle X \rangle = np$, the variance is: $\sigma^2 = np (1-p)$. Thus if $p$ is small we have that $\sigma^2 \simeq np$, that is $\sigma^2 \simeq \langle X \rangle$ and this explains the denominator $E_i$ in $\chi^2$
# </p>
#
# 3. Divide $[0,1]$ into $M$ identical sub-intervals and implement the $\chi^2$ test. Obviously, the number of expected events observed in each sub-interval after $n$ *throws*, according to a uniform distribution, is $np = n\times 1/M= n/M$. Fix $M=10^2$ and use for $n$ the first $10^4$ pseudo-random numbers, then the successive $10^4$ pseudo-random numbers, and so on ... 100 times. <font color="red">Plot $\chi^2_j$ for $j=1, ..., 100$</font>. In this case the chi-square statistic is:
# $$\chi^2 = \sum_{i=1}^M \frac{\left( n_i - n/M \right)^2}{n/M}$$
# We should expect on average that $(n_i - n/M)^2 \simeq n/M$ and thus $\chi^2 \simeq 100$, i.e. the number of sub-intervals.
# A larger value of $\chi^2$ indicates that the hypothesis ($n_i$ are drawn from a uniform distribution) is rather unlikely.

# %% [markdown]
# ### Exercise 01.2
# - Extend Pseudo-Random Number generator downloaded from the NSL Ariel web site and check the Central Limit Theorem:

# %% [markdown]
# 1. <font color="red">Add two probability distributions</font> by using the **method of the inversion of the cumulative distribution** to sample from a **generic** <font color="red">exponential distribution</font>, $p(x) = \lambda \exp(-\lambda x)$, $x\in [0;+\infty]$ (see <a href="https://en.wikipedia.org/wiki/Exponential_distribution">this Wikipedia link</a>), and a **generic** <font color="red">Cauchy-Lorentz distribution</font> $p(x)=\frac{1}{\pi}\frac{\Gamma}{(x-\mu)^2+\Gamma^2}$, $x\in [-\infty;+\infty]$ (see <a href="https://en.wikipedia.org/wiki/Cauchy_distribution">this Wikipedia link</a>).
# 2. <font color="red">Make 3 pictures</font> with the histograms obtained filling them with $10^4$ realizations of $S_N = \frac{1}{N}\sum_{i=1}^N x_i$ (for $N=1, 2, 10, 100$), being $x_i$ a random variable sampled throwing a *standard* dice (fig.1), an *exponential* dice (fig.2, use $\lambda=1$) and a *Lorentzian* dice (fig.3, use $\mu=0$ and $\Gamma=1$).
#
# Note tha you can try to fit the case $N=100$ with a Gaussian for standard and exponential dices, whereas you should use a Cauchy-Lorentz distribution for the last case.

# %% [markdown]
# ### Exercise 01.3
# - **Simulate** the Buffon’s experiment (see LSN_Lecture_00, supplementary material):  A needle of length $L$ is thrown at random onto a horizontal plane ruled with straight lines a distance $d$ (must be $d > L$, but do not use $d\gg L$ otherwise $P\ll 1$) apart. The probability $P$ that the needle will intersect one of these lines is: $P = 2L/\pi d$. This could be used to evaluate $\pi$ from throws of the needle: if the needle is thrown down $N_{thr}$ times and is observed to land on a line $N_{hit}$ of those times, we can make an estimate of $\pi$ from
# $$\pi = \frac{2L}{Pd} = \lim_{N_{thr} \to \infty}\frac{2LN_{thr}}{N_{hit}d}$$
# <font color="red">Make a picture of the estimation of $\pi$ and its uncertainty (Standard Deviation of the mean) with a large number of *throws* $M$ as a function of the number of blocks, $N$</font> (see below: Computing statistical uncertainties). If possible, do not use $\pi$ to evaluate $\pi$.

# %% [markdown]
# ### <span style="color:blue">Computing statistical uncertainties: the blocking method</span>
# - A fundamental step in every Monte Carlo calculation is the estimation of its statistical uncertainty, **it's a must!** Your task would not be completed if you had not calculated it.

# %% [markdown]
# <p style="border:2px; border-style:solid; border-color:#F5F5F5; padding: 1em; background-color:#F5F5F5">
#     In computing the statistical uncertainties, i.e. the standard deviation of the mean, you need an estimation of the variance $\sigma^2$, the second central moment. First of all note that the variance can be computed from
#     $$\sigma^2_A := \langle (A-\langle A\rangle)^2\rangle = \langle A^2 \rangle -\langle A\rangle^2 $$
#     What is the best way to estimate $\sigma^2_A$? Imagine that your Monte Carlo estimation of $A$ is obtained from a calculation which uses $M$ Monte Carlo "steps" (intentionally, here I am generic because what is a single "step" in a Monte Carlo calculation strictly depends on the specific calculation); you can always divide such $M$ Monte Carlo "steps" in $N$ blocks, with $N<M$. In each block, you can use your $M/N$ Monte Carlo "steps" to obtain an estimate of $A$, let me call it $A_i$ with $i=1,N$, and then you have also $A^2_i$ with $i=1,N$.
#     At this point everything becomes clear:
#     $$ \langle A^2 \rangle \simeq \frac{1}{N} \sum_{i=1}^N A^2_i \quad \quad \langle A\rangle^2 \simeq \left( \frac{1}{N} \sum_{i=1}^N A_i \right)^2 $$
#     and finally the statistical uncertainty with $N$ :
#     $$\frac{\sigma}{\sqrt{N-1}} \simeq \sqrt{\frac{1}{N-1} \left[ \frac{1}{N} \sum_{i=1}^N A^2_i - \left( \frac{1}{N} \sum_{i=1}^N A_i \right)^2 \right]} $$
# </p>

# %% [markdown]
# - <font color="blue">In a Monte Carlo calculation, you can use the arguments above to outputting an estimate of A and its statistical uncertainty on the fly, during your calculation. You will be able to do this every $M/N$ steps, and thus, in the end, $N$ times</font>. Note that after the first $M/N$ Monte Carlo steps, at the end of the first block, your estimation of the uncertainty is not computable, so set it to zero and compute it only from the second block. **Question**: $N$ can be chosen in many ways ... what are the limitations regarding this choice?

# %% [markdown]
# # Esercizio 1.1 - <span style="color:deeppink"> Verifiche sul generatore congruenziale lineare </span>

# %% [markdown]
# ### Esercizio 1.1.1 - Stima valor medio di $r$

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.stats import norm , cauchy
import matplotlib.mlab as mlab

# %matplotlib inline

# nicer figures
import matplotlib as mpl
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 12
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

# %%
sum_prog , error_prog  = np.loadtxt( "Esercizio1.1/data.csv" , dtype = float , delimiter = "," , usecols=(0,1) , unpack='true')

# %%
plt.errorbar( np.arange(len(sum_prog)) , sum_prog - 0.5 , yerr=error_prog , color="navy" )
plt.xlabel('Blocks')
plt.ylabel(r'$<r> - 0.5$')
plt.title('Mean value of r')
plt.grid(True)
plt.show()

# %% [markdown]
# Il grafico mostra l'evoluzione del valore medio di una variabile casuale r estratta uniformemente tra 0 e 1 tramite un generatore congruenziale lineare.
# Risulta evidente dal grafico che all'aumentare del numero eventi, il valor medio si avvicina sempre di più al valore atteso 0.5, con il quale è assolutamente compatibile considerando l'incertezza statistica.
# L'incertezza statistica riportata nel grafico è stata calcolata con il metodo delle medie a blocchi. Il numero di estrazioni totali è $10^6$, sono state suddivise in 100 blocchi, cisascuno contenente 10000 stime.

# %% [markdown]
# ## Esercizio 1.1.2 - Stima valor medio di $r^2$

# %%
file = "Esercizio1.1/data_r_square.csv"
sum_prog , error_prog  = np.loadtxt( file , dtype = float , delimiter = "," , usecols=(0,1) , unpack='true')

# %%
plt.errorbar( np.arange(len(sum_prog)) , sum_prog - (1/12) , yerr=error_prog , color = "navy")
plt.xlabel('Blocks')
plt.ylabel(r'$<r-1/2>^2 - 1/12$')
plt.title(r'Mean value of $(r−1/2)^2$')
plt.grid(True)
plt.show()

# %% [markdown]
# Il grafico mostra l'evoluzione del valore medio di una variabile casuale $r^2$, dove r è estratta uniformemente tra 0 e 1 tramite un generatore congruenziale lineare.
# Risulta evidente dal grafico che il valor medio è compatibile con il valore atteso di $1/12$ tenendo conto anche dell'incertezza statistica. Questo è sicuramente un punto che prova la bontà del generatore.
# L'incertezza statistica riportata nel grafico è stata calcolata con il metodo delle medie a blocchi , in particolare ho eseguito $10^6$ estrazioni, che sono state divise in 100 blocchi contenenti 10000 stime ciascuno.

# %% [markdown]
# ## Esercizio 1.1.3 - Test $\chi ^2$ per il generatore di numeri casuali

# %%
file = "Esercizio1.1/data_chi.csv"
chis  = np.loadtxt( file , dtype = float , delimiter = "," , usecols=(0) )
chi = np.mean(chis)

# %%
plt.plot( np.arange(len(chis)) , chis , color="Navy" , marker ="*")
plt.axhline(chi, color="indigo" , linestyle="solid" , label="Valore medio: "+str(round(chi, 2)))
plt.xlabel('Numero di tentativi')
plt.ylabel(r"$\chi ^2$")
plt.title(r"$\chi ^2$ test on the random number generator")
plt.legend(loc=(1.1 , 0.7))
plt.grid(True)
plt.show()

# %% [markdown]
# Il grafico riporta cento risultati del test statistico del $\chi ^2$. Ogni valore è stato calcolato estraendo 10000 numeri pseudo casuali. I valori oscillano attorno ad un valor medio molto vicino a 100, che è il valore che mi aspetterei di trovare. Le oscillazioni sembrano molto ampie, in realtà la varianza che mi aspetto di trovare in questa distribuzione è circa 100, che corrisponde ad una $\sigma$ di 10, che effettivamente include la maggior parte dei dati trovati.

# %% [markdown]
# # Esercizio 1.2 - Verifica del teorema del limite centrale

# %%
file = "Esercizio1.2/dices.csv"
uniform , exponential , lorentz   = np.loadtxt( file , dtype = float , delimiter = "," , usecols=(0,1,2) , unpack='true')

# %%
uni_1 , uni_2 , uni_10, uni_100 = np.split(uniform , 4)
exp_1 , exp_2 , exp_10 , exp_100 = np.split(exponential , 4)
lor_1 , lor_2 , lor_10 , lor_100 = np.split(lorentz , 4)

# %%
N = [1 ,2 , 10 , 100]
fig, [ax0 , ax1 , ax2 , ax3]   = plt.subplots(1, 4, figsize=(20 , 5))

ax0.hist( uni_1 , bins="auto" , color="lightseagreen" , density=True)
ax1.hist( uni_2 , bins="auto" , color="lightseagreen" , density=True)
ax2.hist( uni_10 , bins="auto" , color="lightseagreen" , density=True)
ax3.hist( uni_100 , bins="auto" , color="lightseagreen" , density=True)


#fitting gaussiana
mu, std = norm.fit(uni_100)

x = np.linspace(0.3, 0.7, 100)
p = norm.pdf(x, mu, std)
ax3.plot(x, p, color= "orangered", linewidth=1.8)

for i in range(4):
    globals()['ax'+str(i)].set_title(f"Uniform, N={N[i]}")
    globals()['ax'+str(i)].set_ylabel(f"Distribution of $S_N$")
 
    
print( r"Parametri ottimizzati: (mu , sigma)")
(mu , std)
# Out:
# Parametri ottimizzati: (mu , sigma)
# (0.5000108001, 0.029037794697737294)

# %% [markdown]
# Ogni grafico è stato ottenuto estraendo 10000 numeri casuali nell'intervallo (0 , 1). N è il numero di estrazioni che vengono mediate per produrre un valore nel grafico. Come previsto dal teorema del limite centrale, una variabile aleatoria data dalla somma di N variabili indipendenti distribuite uniformemente, ha una distribuzione che converge a quella gaussiana nel limite $ N \rightarrow \infty $.

# %%
fig, [ax0 , ax1 , ax2 , ax3]   = plt.subplots(1, 4, figsize=(20 , 5))

ax0.hist( exp_1 , bins="auto" , color="plum", density=True)
ax1.hist( exp_2 , bins="auto", color="plum", density=True)
ax2.hist( exp_10 , bins="auto" , color="plum", density=True)
ax3.hist( exp_100 , bins="auto" , color="plum", density=True)

mu, std = norm.fit(exp_100)

x = np.linspace(0.5, 1.5, 100)
p = norm.pdf(x, mu, std)
ax3.plot(x, p, color= "orangered", linewidth=1.8 , label="Theorical distribution")

for i in range(4):
    globals()['ax'+str(i)].set_title(f"Exponential, N={N[i]}")
    globals()['ax'+str(i)].set_ylabel(f"Distribution of $S_N$")
    
print("Parametri ottimizzati: (mu , sigma)")
(mu , std)
# Out:
# Parametri ottimizzati: (mu , sigma)
# (0.9998264965999999, 0.09851158906206817)

# %% [markdown]
# Ogni grafico è stato ottenuto estraendo 10000 numeri casuali nell'intervallo (0 , 1). Di nuovo è verificato il teorema del limite centrale, la somma di variabili aletorie distribuite esponenzialmente ha come bacino di convergenza una distribuzione normale.

# %%
fig, [ax0 , ax1 , ax2 , ax3] = plt.subplots(1, 4, figsize=(20 , 5))


ax0.hist( lor_1 , bins="auto"  , range=(-15,15) , color="palegreen", density=True)
ax1.hist( lor_2 , bins="auto" , range=(-15,15)  , color="palegreen", density=True)
ax2.hist( lor_10 , bins="auto" , range=(-15,15) , color="palegreen", density=True)
ax3.hist( lor_100 , bins="auto" , range=(-15,15) , color="palegreen", density=True)

#fitting lorentziana
mu, gamma = cauchy.fit(lor_100)

x = np.linspace(-15, 15, 100)
p = cauchy.pdf(x ,mu, gamma)
ax3.plot(x, p, color= "orangered", linewidth=1.8)

for i in range(4):
    globals()['ax'+str(i)].set_title(f"Lorentz, N={N[i]}")
    globals()['ax'+str(i)].set_ylabel(f"Distribution of $S_N$")
    
print("Parametri ottimizzati: (mu , gamma)")
(mu , gamma)
# Out:
# Parametri ottimizzati: (mu , gamma)
# (-0.010155445369008923, 1.0041842049789673)

# %% [markdown]
# Ogni grafico è stato ottenuto estraendo 10000 numeri casuali nell'intervallo (0 , 1). Per la distribuzione di Lorentz si verifica un comportamento leggermente diverso, si trova che la somma di variabili casuali indipendenti con distribuzione lorentziana converge ad una lorenziana. La distribuzione di Lorentz quindi vive in un diverso bacino di convergenza rispetto alle distribuzioni uniforme ed esponenziale.

# %% [markdown]
# # Esercizio 1.3 - Esperimento di Buffon

# %%
file = "Esercizio1.3/data_pi.csv"
prog_pi , prog_error  = np.loadtxt( file , dtype = float , delimiter = "," , usecols=(0,1) , unpack='true')

# %%
plt.errorbar( np.arange(len(prog_pi)) , prog_pi , yerr=prog_error ,  color="Navy" )
plt.axhline(np.pi, color="indigo" , linestyle="solid" , label="Valore atteso: "+str(round(np.pi, 5)) )
plt.xlabel('Numero di blocchi')
plt.ylabel(r"$\pi$")
plt.title(r"Stima progressiva del valore di $\pi$")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %% [markdown]
# La figura rappresenta la stima progressiva del valore di $ \pi $ nei blocchi. La stima in ciascun blocco si è ottenuta lanciando la sbarretta $10^5$ volte. Nel codice non è stato usato il valore di $\pi$ noto a priori, per campionare il $ sen(\theta) $ si sono estratti due numeri casuali $u \in [-1,1]$ e $v \in [0,1]$, da cui si calcola $ sen(\theta) = \frac{2uv} {(u^2 + v^2)} $.
#
# Non è necessario utilizzare varie righe ma ne basta porre una sola, poichè il problema presenta invarianza traslazionale lungo l'asse delle y, ossia tutti i casi si possono ricondurre tramite una traslazione a questo caso.
# Non è stato neanche necessario estrarre la posizione in x della sbarretta poichè l'unico dato di interesse è l'intersezione. Per lanciare un ago, estraggo uniformemente la coordinata y di un estremo dell'intervallo (0,1), e la y dell'altro estremo viene ricavata dal campionamento del $sen(\theta)$. A questo punto è facile determinare se  l'intersezione con la linea orizzontale avviene o meno.
